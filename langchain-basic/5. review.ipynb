# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2:1b")
# Out:
# c:\Users\dev-euna\Desktop\AI_AGENT_STUDY\langchain-basic\langchain-basic\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
# 음식 이름 찾기
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

food_prompt = PromptTemplate(
    template = """What is the most popular food in {country}? Please return the name of the food only""",
    input_variables = ['country']
)

food_chain = food_prompt | llm | StrOutputParser()

# %%
food_chain.invoke({'country': 'South Korea'})
# Out:
# 'Bibimbap'

# %%
# 음식 레시피 찾기

from langchain_core.prompts import ChatPromptTemplate

recipe_prompt = ChatPromptTemplate.from_messages([
    ('system', 'Provide the recipe of the food that user wants. Please return the recipe only as a numbered list'),
    ("human", "Can you give me the recipe for making {food}?")
])

recipe_chain = recipe_prompt | llm | StrOutputParser()

# %%
recipe_chain.invoke({'food': 'bibimbap'})
# Out:
# "Here's a traditional Korean recipe for bibimbap:\n\n**Servings:** 4-6\n\n**Ingredients:**\n\n1. 200g mixed vegetables (zucchini, carrots, bean sprouts, etc.)\n2. 200g cooked white rice\n3. 1/2 cup mixed kimchi (spicy Korean fermented cabbage)\n4. 1/4 cup chopped green onions\n5. 1/4 cup toasted sesame seeds\n6. 2 eggs, sliced\n7. 1/4 cup diced cucumber\n8. 1/4 cup diced red bell pepper\n9. 1 tablespoon Gochujang (Korean chili paste)\n10. 1 tablespoon soy sauce\n11. 1 tablespoon rice vinegar\n12. 1 teaspoon sesame oil\n13. Salt and black pepper, to taste\n14. 2 tablespoons sesame oil (for serving)\n\n**Instructions:**\n\n1. Prepare the ingredients:\n\t* Cut the mixed vegetables into thin strips.\n\t* Chop the green onions, sesame seeds, and cucumber into small pieces.\n\t* Boil the eggs and slice them into wedges.\n\t* Slice the cucumbers and bell peppers.\n2. Cook the rice:\n\t* Cook the white rice according to the package instructions.\n\t* Let it cool down.\n3. Assemble the bibimbap:\n\t* Place a scoop of cooked rice in a bowl.\n\t* Arrange the mixed vegetables, kimchi, and sesame seeds on top of the rice.\n\t* Place a slice of egg in the center of the bowl.\n\t* Add the chopped green onions, cucumber, and red bell pepper around the egg.\n\t* Drizzle Gochujang, soy sauce, and rice vinegar over the ingredients.\n4. Serve:\n\t* Drizzle the sesame oil over the bibimbap.\n\t* Serve immediately and enjoy!\n\n**Tips:**\n\n* Use a variety of colorful vegetables to make the dish visually appealing.\n* Adjust the level of spiciness to your liking by adding more or less Gochujang.\n* You can also add other toppings such as diced chicken, boiled tofu, or pickled ginger to the bibimbap."

# %%
final_chain = {"food": food_chain} | recipe_chain
final_chain.invoke({'country': 'France'})
# Out:
# "Here is the recipe for Pain au Chocolat, a French pastry filled with rich chocolate:\n\n1. 1 1/2 sticks (12 tablespoons) unsalted butter, softened\n2. 1/2 cup granulated sugar\n3. 4 large eggs\n4. 2 1/4 cups all-purpose flour\n5. 1 teaspoon baking powder\n6. 1/4 teaspoon salt\n7. 1 cup dark chocolate chips (at least 70% cocoa)\n8. 1 teaspoon pure vanilla extract\n9. Confectioners' sugar for dusting (optional)\n\nInstructions:\n\n10. In a medium bowl, whisk together flour, baking powder, and salt. Set aside.\n11. In a large bowl, cream the butter and sugar until light and fluffy.\n12. Beat in the eggs one at a time, then stir in the flour mixture until just combined.\n13. Melt the chocolate in a double boiler or in the microwave in 30-second increments, stirring between each interval.\n14. Allow the chocolate to cool slightly, then fold it into the batter until well combined.\n15. Turn the dough out onto a floured surface and knead a few times until it comes together.\n16. Roll out the dough to a thickness of about 1/4 inch (6 mm).\n17. Cut out rectangles of dough, about 4 inches (10 cm) wide and 6 inches (15 cm) long.\n18. Place a spoonful of the chocolate filling in the center of each rectangle.\n19. Fold the dough over the filling to form a triangle, and press the edges to seal.\n20. Use a knife or a pastry brush to create a decorative edge.\n21. Place the pastries on a baking sheet lined with parchment paper, leaving about 1 inch (2.5 cm) of space between each.\n22. Brush the tops with egg wash and sprinkle with confectioners' sugar (if desired).\n23. Bake in a preheated oven at 375°F (190°C) for 18-20 minutes, or until golden brown.\n24. Allow the pastries to cool on a wire rack for 5-10 minutes before serving.\n\nEnjoy your Pain au Chocolat!"
